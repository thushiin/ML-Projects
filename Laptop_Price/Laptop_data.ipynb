# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('laptopData.csv')
df
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1273 non-null   object
#  3   Inches            1273 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1273 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1273 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.drop(['Unnamed: 0','ScreenResolution','Weight'],axis=1,inplace=True)

# %%
df=df.dropna(axis=0,how='any')

# %%
df.head()
# Out:
#   Company   TypeName Inches                         Cpu   Ram  \
# 0   Apple  Ultrabook   13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Ultrabook   13.3        Intel Core i5 1.8GHz   8GB
# 2      HP   Notebook   15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  Ultrabook   15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  Ultrabook   13.3        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys        Price
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS   71378.6832
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS   47895.5232
# 2            256GB SSD         Intel HD Graphics 620  No OS   30636.0000
# 3            512GB SSD            AMD Radeon Pro 455  macOS  135195.3360
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS   96095.8080

# %%
df['Cpu'].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Core i5 7300HQ 2.5GHz',
#        'AMD E-Series E2-9000e 1.5GHz', 'Intel Core i5 1.6GHz',
#        'Intel Core i7 8650U 1.9GHz', 'Intel Atom x5-Z8300 1.44GHz',
#        'AMD E-Series E2-6110 1.5GHz', 'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
df['Cpu']=df['Cpu'].str.split().str[:3].str.join(sep=" ")
# Out:
# <ipython-input-67-bf562b79f7fd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].str.split().str[:3].str.join(sep=" ")

# %%
df['Cpu']=df['Cpu'].str.replace(' 9420','')
df['Cpu']=df['Cpu'].str.replace(' E2-9000e','')
df['Cpu']=df['Cpu'].str.replace(' E2-6110','')
df['Cpu']=df['Cpu'].str.replace(' 9220','')
df['Cpu']=df['Cpu'].str.replace(' 6110','')
df['Cpu']=df['Cpu'].str.replace(' 9000e','')
df['Cpu']=df['Cpu'].str.replace(' A10-9620P','')
df['Cpu']=df['Cpu'].str.replace(' A6-9220','')
df['Cpu']=df['Cpu'].str.replace(' 9600P','')
df['Cpu']=df['Cpu'].str.replace(' 7410','')
df['Cpu']=df['Cpu'].str.replace(' 9720P','')
df['Cpu']=df['Cpu'].str.replace(' 7110','')
df['Cpu']=df['Cpu'].str.replace(' 9620P','')
df['Cpu']=df['Cpu'].str.replace(' A9-9420','')
df['Cpu']=df['Cpu'].str.replace(' E2-9000','')
df['Cpu']=df['Cpu'].str.replace(' 7310','')
df['Cpu']=df['Cpu'].str.replace(' 9700P','')
df['Cpu']=df['Cpu'].str.replace(' 7210','')
df['Cpu']=df['Cpu'].str.replace(' 9000','')
df['Cpu']=df['Cpu'].str.replace(' 9410','')
df['Cpu']=df['Cpu'].str.replace(' x5-Z8300','')
df['Cpu']=df['Cpu'].str.replace(' x5-Z8350','')
df['Cpu']=df['Cpu'].str.replace(' x5-Z8550','')
df['Cpu']=df['Cpu'].str.replace(' X5-Z8350','')
df['Cpu']=df['Cpu'].str.replace(' 1700','')
df['Cpu']=df['Cpu'].str.replace(' Z8350','')
df['Cpu']=df['Cpu'].str.replace(' 1600','')
# Out:
# <ipython-input-68-855877aa4688>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].str.replace(' 9420','')
# <ipython-input-68-855877aa4688>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].str.replace(' E2-9000e','')
# <ipython-input-68-855877aa4688>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['Cpu'].isnull().sum()
# Out:
# 0

# %%
df['Ram'].unique()
# Out:
# array(['8GB', '16GB', '4GB', '2GB', '12GB', '64GB', '6GB', '32GB', '24GB',
#        '1GB'], dtype=object)

# %%
df['Ram']=df['Ram'].str.replace('GB','')
# Out:
# <ipython-input-72-79fd15836a27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].str.replace('GB','')

# %%
df['Ram'].isnull().sum()
# Out:
# 0

# %%
df['Memory'].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '128GB SSD +  1TB HDD', '256GB SSD +  256GB SSD',
#        '64GB Flash Storage', '32GB Flash Storage', '256GB SSD +  1TB HDD',
#        '256GB SSD +  2TB HDD', '32GB SSD', '2TB HDD', '64GB SSD',
#        '1.0TB Hybrid', '512GB SSD +  1TB HDD', '1TB SSD',
#        '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '?', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
df['Memory']=df['Memory'].replace('?',np.nan)
# Out:
# <ipython-input-76-d11c8b7380cb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].replace('?',np.nan)

# %%
df['Memory'].isnull().sum()
# Out:
# 1

# %%
df['Memory']=df['Memory'].fillna(method='ffill')
# Out:
# <ipython-input-78-bec4a9ce625a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].fillna(method='ffill')

# %%
# memory1=[]
# memory2=[]
# for i in df['Memory']:
#   if '+' in i:
#     i=i.split(' +  ')
#     m1=i[0]
#     m2=i[1]
#   else:
#     m1=i
#     m2='No Memory'
#   memory1.append(m1)
#   memory2.append(m2)

# %%
# df['mem1']=memory1
# df['mem2']=memory2

# %%
df[['Memory1','Memory2']] = df['Memory'].str.split(' + ', expand=True)
# Out:
# <ipython-input-82-4d9a9ad32554>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Memory1','Memory2']] = df['Memory'].str.split(' + ', expand=True)
# <ipython-input-82-4d9a9ad32554>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['Memory1','Memory2']] = df['Memory'].str.split(' + ', expand=True)

# %%
df['Memory2'].isnull().sum()
# Out:
# 1069

# %%
df['Memory1'].value_counts()
# Out:
# 256GB SSD               401
# 1TB HDD                 218
# 500GB HDD               130
# 512GB SSD               116
# 128GB SSD +              94
# 256GB SSD +              86
# 128GB SSD                74
# 32GB Flash Storage       37
# 512GB SSD +              20
# 2TB HDD                  16
# 64GB Flash Storage       14
# 1TB SSD                  13
# 1.0TB Hybrid              9
# 256GB Flash Storage       8
# 16GB Flash Storage        7
# 32GB SSD                  6
# 128GB Flash Storage       4
# 180GB SSD                 4
# 16GB SSD                  3
# 1TB SSD +                 2
# 512GB Flash Storage       2
# 128GB HDD                 1
# 508GB Hybrid              1
# 8GB SSD                   1
# 240GB SSD                 1
# 64GB Flash Storage +      1
# 32GB HDD                  1
# 1TB HDD +                 1
# 64GB SSD                  1
# 1.0TB HDD                 1
# Name: Memory1, dtype: int64

# %%
df['Memory1']=df['Memory1'].str.replace('+','')
df['Memory1']=df['Memory1'].str.rstrip()
df['Memory2']=df['Memory2'].replace(np.nan,'No memory')
# Out:
# <ipython-input-85-484e3f67e361>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Memory1']=df['Memory1'].str.replace('+','')
# <ipython-input-85-484e3f67e361>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory1']=df['Memory1'].str.replace('+','')
# <ipython-input-85-484e3f67e361>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head()
# Out:
#   Company   TypeName Inches            Cpu Ram               Memory  \
# 0   Apple  Ultrabook   13.3  Intel Core i5   8            128GB SSD
# 1   Apple  Ultrabook   13.3  Intel Core i5   8  128GB Flash Storage
# 2      HP   Notebook   15.6  Intel Core i5   8            256GB SSD
# 3   Apple  Ultrabook   15.4  Intel Core i7  16            512GB SSD
# 4   Apple  Ultrabook   13.3  Intel Core i5   8            256GB SSD
#
#                             Gpu  OpSys        Price              Memory1  \
# 0  Intel Iris Plus Graphics 640  macOS   71378.6832            128GB SSD
# 1        Intel HD Graphics 6000  macOS   47895.5232  128GB Flash Storage
# 2         Intel HD Graphics 620  No OS   30636.0000            256GB SSD
# 3            AMD Radeon Pro 455  macOS  135195.3360            512GB SSD
# 4  Intel Iris Plus Graphics 650  macOS   96095.8080            256GB SSD
#
#      Memory2
# 0  No memory
# 1  No memory
# 2  No memory
# 3  No memory
# 4  No memory

# %%
df['Memory2'].isnull().sum()
# Out:
# 0

# %%
df['Memory2'].unique()
# Out:
# array(['No memory', '1TB HDD', '256GB SSD', '2TB HDD', '500GB HDD',
#        '512GB SSD', '1.0TB Hybrid'], dtype=object)

# %%
df.drop('Memory',axis=1,inplace=True)
# Out:
# <ipython-input-89-e879fc67a178>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Memory',axis=1,inplace=True)

# %%
df = df.reindex(columns=['Company','TypeName','Inches','Cpu','Ram','Memory1','Memory2','Gpu','OpSys','Price'])

# %%
df['Gpu'].unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Nvidia GeForce GTX 1050', 'AMD Radeon R2',
#        'AMD Radeon 530', 'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Intel HD Graphics 400', 'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
df['Gpu']=df['Gpu'].str.split().str[:3].str.join(sep=" ")

# %%
# df['Gpu']=df['Gpu'].fillna(method='ffill')

# %%
df['Gpu'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Company     0
# TypeName    0
# Inches      0
# Cpu         0
# Ram         0
# Memory1     0
# Memory2     0
# Gpu         0
# OpSys       0
# Price       0
# dtype: int64

# %%
df['Inches']=df['Inches'].replace('?',np.nan)

# %%
df['Inches'].isnull().sum()
# Out:
# 1

# %%
df['Inches']=df['Inches'].fillna(method='ffill')

# %%
df.dtypes
# Out:
# Company      object
# TypeName     object
# Inches       object
# Cpu          object
# Ram          object
# Memory1      object
# Memory2      object
# Gpu          object
# OpSys        object
# Price       float64
# dtype: object

# %%
df['Inches']=df['Inches'].astype(float)
df['Ram']=df['Ram'].astype(int)

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram              Memory1  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8            128GB SSD
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  128GB Flash Storage
# 2      HP   Notebook    15.6  Intel Core i5    8            256GB SSD
# 3   Apple  Ultrabook    15.4  Intel Core i7   16            512GB SSD
# 4   Apple  Ultrabook    13.3  Intel Core i5    8            256GB SSD
#
#      Memory2                Gpu  OpSys        Price
# 0  No memory    Intel Iris Plus  macOS   71378.6832
# 1  No memory  Intel HD Graphics  macOS   47895.5232
# 2  No memory  Intel HD Graphics  No OS   30636.0000
# 3  No memory     AMD Radeon Pro  macOS  135195.3360
# 4  No memory    Intel Iris Plus  macOS   96095.8080

# %%
df.to_csv('cleaned_laptop_data.csv')

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df['Company']=label.fit_transform(df['Company'])
df['TypeName']=label.fit_transform(df['TypeName'])
df['Cpu']=label.fit_transform(df['Cpu'])
df['Memory1']=label.fit_transform(df['Memory1'])
df['Memory2']=label.fit_transform(df['Memory2'])
df['Gpu']=label.fit_transform(df['Gpu'])
df['OpSys']=label.fit_transform(df['OpSys'])

# %%
df.head()
# Out:
#    Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys  \
# 0        1         4    13.3   15    8        4        6   20      8
# 1        1         4    13.3   15    8        2        6   18      8
# 2        7         3    15.6   15    8       12        6   18      4
# 3        1         4    15.4   16   16       20        6    8      8
# 4        1         4    13.3   15    8       12        6   20      8
#
#          Price
# 0   71378.6832
# 1   47895.5232
# 2   30636.0000
# 3  135195.3360
# 4   96095.8080

# %%
y=df['Price']
x=df.drop('Price',axis=1)

# %%
x
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 0           1         4    13.3   15    8        4        6   20      8
# 1           1         4    13.3   15    8        2        6   18      8
# 2           7         3    15.6   15    8       12        6   18      4
# 3           1         4    15.4   16   16       20        6    8      8
# 4           1         4    13.3   15    8       12        6   20      8
# ...       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 1298       10         0    14.0   16    4        4        6   18      5
# 1299       10         0    13.3   16   16       20        6   18      5
# 1300       10         3    14.0   11    2       21        6   18      5
# 1301        7         3    15.6   16    6        8        6   12      5
# 1302        2         3    15.6   11    4       17        6   18      5
#
# [1273 rows x 9 columns]

# %%
y
# Out:
# 0        71378.6832
# 1        47895.5232
# 2        30636.0000
# 3       135195.3360
# 4        96095.8080
#            ...
# 1298     33992.6400
# 1299     79866.7200
# 1300     12201.1200
# 1301     40705.9200
# 1302     19660.3200
# Name: Price, Length: 1273, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(xtrain,ytrain)
rf.predict([[1,4,13.3,15,8,4,6,20,8]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([68932.792428])

# %%
rf.score(xtest,ytest)
# Out:
# 0.7724370245793609

# %%
import pickle
file=open('laptopdata.pkl','wb')
pickle.dump(rf,file)

# %%
# !pip install pandas

# %%
x
# Out:
#       Company  TypeName  Inches  Cpu  Ram  Memory1  Memory2  Gpu  OpSys
# 0           1         4    13.3   15    8        4        6   20      8
# 1           1         4    13.3   15    8        2        6   18      8
# 2           7         3    15.6   15    8       12        6   18      4
# 3           1         4    15.4   16   16       20        6    8      8
# 4           1         4    13.3   15    8       12        6   20      8
# ...       ...       ...     ...  ...  ...      ...      ...  ...    ...
# 1298       10         0    14.0   16    4        4        6   18      5
# 1299       10         0    13.3   16   16       20        6   18      5
# 1300       10         3    14.0   11    2       21        6   18      5
# 1301        7         3    15.6   16    6        8        6   12      5
# 1302        2         3    15.6   11    4       17        6   18      5
#
# [1273 rows x 9 columns]

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1273 entries, 0 to 1302
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 1273 non-null   float64
# dtypes: float64(1)
# memory usage: 19.9 KB

# %%
x=np.array(x)
y=np.array(y)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
import pandas as pd
from sklearn.model_selection import cross_val_score,KFold
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor

models=[LinearRegression(), SVR(),DecisionTreeRegressor(),RandomForestRegressor()]

kf=KFold(n_splits=3)
for model in models:
    print(type(x))
    print(type(y))

    scores= cross_val_score(model, x, y, cv=kf)
    print(f"Model: {model.__class__.__name__}")
    print(f"  Cross-validation scores: {scores}")
    print(f"  Mean accuracy: {np.mean(scores):.2f}")
    print()
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Model: LinearRegression
#   Cross-validation scores: [0.56791314 0.57061017 0.56945139]
#   Mean accuracy: 0.57
#
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Model: SVR
#   Cross-validation scores: [0.17133    0.19076115 0.17310525]
#   Mean accuracy: 0.18
#
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Model: DecisionTreeRegressor
#   Cross-validation scores: [0.62943908 0.75397189 0.70764503]
#   Mean accuracy: 0.70
#
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# Model: RandomForestRegressor
#   Cross-validation scores: [0.77212727 0.83339893 0.78405285]
#   Mean accuracy: 0.80
