# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', 50)
df=pd.read_csv('Jan_2019_ontime.csv')
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0                  1            2                9E                  20363
# 1                  1            2                9E                  20363
# 2                  1            2                9E                  20363
# 3                  1            2                9E                  20363
# 4                  1            2                9E                  20363
# ...              ...          ...               ...                    ...
# 583980            31            4                UA                  19977
# 583981            31            4                UA                  19977
# 583982            31            4                UA                  19977
# 583983            31            4                UA                  19977
# 583984            31            4                UA                  19977
#
#        OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583985 entries, 0 to 583984
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   DAY_OF_MONTH           583985 non-null  int64
#  1   DAY_OF_WEEK            583985 non-null  int64
#  2   OP_UNIQUE_CARRIER      583985 non-null  object
#  3   OP_CARRIER_AIRLINE_ID  583985 non-null  int64
#  4   OP_CARRIER             583985 non-null  object
#  5   TAIL_NUM               581442 non-null  object
#  6   OP_CARRIER_FL_NUM      583985 non-null  int64
#  7   ORIGIN_AIRPORT_ID      583985 non-null  int64
#  8   ORIGIN_AIRPORT_SEQ_ID  583985 non-null  int64
#  9   ORIGIN                 583985 non-null  object
#  10  DEST_AIRPORT_ID        583985 non-null  int64
#  11  DEST_AIRPORT_SEQ_ID    583985 non-null  int64
#  12  DEST                   583985 non-null  object
#  13  DEP_TIME               567633 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH                  0
# DAY_OF_WEEK                   0
# OP_UNIQUE_CARRIER             0
# OP_CARRIER_AIRLINE_ID         0
# OP_CARRIER                    0
# TAIL_NUM                   2543
# OP_CARRIER_FL_NUM             0
# ORIGIN_AIRPORT_ID             0
# ORIGIN_AIRPORT_SEQ_ID         0
# ORIGIN                        0
# DEST_AIRPORT_ID               0
# DEST_AIRPORT_SEQ_ID           0
# DEST                          0
# DEP_TIME                  16352
# DEP_DEL15                 16355
# DEP_TIME_BLK                  0
# ARR_TIME                  17061
# ARR_DEL15                 18022
# CANCELLED                     0
# DIVERTED                      0
# DISTANCE                      0
# Unnamed: 21              583985
# dtype: int64

# %%
df['OP_UNIQUE_CARRIER'].unique()
# Out:
# array(['9E', 'AA', 'MQ', 'G4', 'OH', 'B6', 'YV', 'EV', 'F9', 'YX', 'HA',
#        'NK', 'OO', 'WN', 'AS', 'UA', 'DL'], dtype=object)

# %%
df['DELAYED'] = (df['ARR_DEL15'].astype(bool) | df['DEP_DEL15'].astype(bool)).astype(int)

# %%
df.drop(['OP_CARRIER','ORIGIN_AIRPORT_SEQ_ID','DEST_AIRPORT_SEQ_ID','Unnamed: 21','OP_CARRIER_AIRLINE_ID','TAIL_NUM','OP_CARRIER_FL_NUM','ORIGIN_AIRPORT_ID','DEST_AIRPORT_ID','CANCELLED','DIVERTED','ARR_DEL15','DEP_DEL15'],axis=1,inplace=True)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  DEP_TIME  \
# 0                  1            2                9E    GNV  ATL     601.0
# 1                  1            2                9E    MSP  CVG    1359.0
# 2                  1            2                9E    DTW  CVG    1215.0
# 3                  1            2                9E    TLH  ATL    1521.0
# 4                  1            2                9E    ATL  FSM    1847.0
# ...              ...          ...               ...    ...  ...       ...
# 583980            31            4                UA    GUM  HNL     749.0
# 583981            31            4                UA    GUM  SPN     717.0
# 583982            31            4                UA    SPN  GUM     857.0
# 583983            31            4                UA    SPN  GUM    1820.0
# 583984            31            4                UA    GUM  SPN    1636.0
#
#        DEP_TIME_BLK  ARR_TIME  DISTANCE  DELAYED
# ...

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (566924, 10)

# %%
df.isnull().sum()
# Out:
# DAY_OF_MONTH         0
# DAY_OF_WEEK          0
# OP_UNIQUE_CARRIER    0
# ORIGIN               0
# DEST                 0
# DEP_TIME             0
# DEP_TIME_BLK         0
# ARR_TIME             0
# DISTANCE             0
# DELAYED              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 566924 entries, 0 to 583984
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DAY_OF_MONTH       566924 non-null  int64
#  1   DAY_OF_WEEK        566924 non-null  int64
#  2   OP_UNIQUE_CARRIER  566924 non-null  object
#  3   ORIGIN             566924 non-null  object
#  4   DEST               566924 non-null  object
#  5   DEP_TIME           566924 non-null  float64
#  6   DEP_TIME_BLK       566924 non-null  object
#  7   ARR_TIME           566924 non-null  float64
#  8   DISTANCE           566924 non-null  float64
#  9   DELAYED            566924 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 47.6+ MB

# %%
df['ORIGIN'].unique()
# Out:
# array(['GNV', 'MSP', 'DTW', 'TLH', 'ATL', 'DAY', 'JAN', 'LGA', 'JAX',
#        'BMI', 'CAK', 'PHL', 'JFK', 'AGS', 'LIT', 'IND', 'EYW', 'CAE',
#        'CWA', 'TRI', 'BOS', 'MGM', 'MDT', 'MKE', 'TVC', 'FSM', 'BHM',
#        'PIA', 'CVG', 'GTR', 'SDF', 'BNA', 'SAT', 'LFT', 'MSN', 'DSM',
#        'EVV', 'ABE', 'DCA', 'BWI', 'ILM', 'TYS', 'LEX', 'CLE', 'ELM',
#        'EWN', 'PHF', 'SHV', 'CSG', 'TUL', 'BDL', 'DFW', 'RIC', 'RAP',
#        'PIT', 'CRW', 'GPT', 'CHA', 'OMA', 'IAD', 'RDU', 'SAV', 'GRR',
#        'BTV', 'LAN', 'OAJ', 'AEX', 'CHO', 'CHS', 'HRL', 'ORF', 'MOT',
#        'HSV', 'MCO', 'BTR', 'LAX', 'ORD', 'PHX', 'MIA', 'CMH', 'SFO',
#        'SEA', 'STL', 'CLT', 'LAS', 'OAK', 'BUF', 'FLL', 'SJU', 'ALB',
#        'PWM', 'SMF', 'MHT', 'TPA', 'EGE', 'OGG', 'HNL', 'MSY', 'IAH',
#        'KOA', 'DEN', 'SAN', 'TUS', 'SJC', 'PBI', 'SNA', 'GRI', 'SLC',
#        'FAT', 'EWR', 'JAC', 'MCI', 'PNS', 'ELP', 'AUS', 'ABQ', 'PSP',
# ...

# %%
df['DEST'].unique()
# Out:
# array(['ATL', 'CVG', 'FSM', 'MSP', 'LGA', 'BMI', 'DAY', 'DTW', 'RIC',
#        'EWR', 'AGS', 'OAJ', 'GNV', 'EYW', 'CWA', 'CAE', 'MGM', 'BNA',
#        'LNK', 'TVC', 'PIA', 'BHM', 'AVP', 'LAN', 'TYS', 'PIT', 'JAX',
#        'GTR', 'BOS', 'MSN', 'JFK', 'DSM', 'EVV', 'MDT', 'OMA', 'AVL',
#        'SHV', 'ILM', 'EWN', 'GTF', 'RDU', 'LEX', 'ABE', 'SDF', 'MYR',
#        'PWM', 'SYR', 'CSG', 'ELM', 'HSV', 'TUL', 'GRB', 'TLH', 'CRW',
#        'TRI', 'LIT', 'GRR', 'IND', 'GPT', 'GSO', 'CHA', 'IAD', 'JAN',
#        'ROC', 'TPA', 'CLE', 'AEX', 'BUF', 'CHO', 'BWI', 'BTV', 'HRL',
#        'PHF', 'CHS', 'ORF', 'SAV', 'SAT', 'LAX', 'SJC', 'DFW', 'ORD',
#        'SEA', 'PHX', 'MIA', 'PHL', 'SFO', 'STL', 'CLT', 'SJU', 'DCA',
#        'MCO', 'TUS', 'ALB', 'FLL', 'AUS', 'EGE', 'HNL', 'OGG', 'IAH',
#        'LAS', 'KOA', 'MSY', 'SAN', 'PDX', 'BOI', 'ATW', 'SPS', 'SLC',
#        'FAT', 'JAC', 'MCI', 'PNS', 'ELP', 'SNA', 'ABQ', 'GSP', 'DEN',
# ...

# %%
df['DEP_TIME_BLK'].unique()
# Out:
# array(['0600-0659', '1400-1459', '1200-1259', '1500-1559', '1900-1959',
#        '0900-0959', '1000-1059', '2000-2059', '1300-1359', '1100-1159',
#        '0800-0859', '2200-2259', '1600-1659', '1700-1759', '2100-2159',
#        '0700-0759', '1800-1859', '0001-0559', '2300-2359'], dtype=object)

# %%
df['DEP_TIME'].nunique()
# Out:
# 1438

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  DEP_TIME  \
# 0             1            2                9E    GNV  ATL     601.0
# 1             1            2                9E    MSP  CVG    1359.0
# 2             1            2                9E    DTW  CVG    1215.0
# 3             1            2                9E    TLH  ATL    1521.0
# 4             1            2                9E    ATL  FSM    1847.0
#
#   DEP_TIME_BLK  ARR_TIME  DISTANCE  DELAYED
# 0    0600-0659     722.0     300.0        0
# 1    1400-1459    1633.0     596.0        0
# 2    1200-1259    1329.0     229.0        0
# 3    1500-1559    1625.0     223.0        0
# 4    1900-1959    1940.0     579.0        0

# %%
df.shape
# Out:
# (566924, 10)

# %%
print('max distance: ', df['DISTANCE'].max(), '\n' ,'min distance: ', df['DISTANCE'].min())
# Out:
# max distance:  4983.0
#  min distance:  31.0

# %%
df['DIST_GROUP'] = 'SHORT'
df.loc[(df['DISTANCE'] > 1000.0) & (df['DISTANCE'] <= 3000.0), 'DIST_GROUP'] = 'MEDIUM'
df.loc[(df['DISTANCE'] > 3000.0), 'DIST_GROUP'] = 'LONG'

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  DEP_TIME  \
# 0                  1            2                9E    GNV  ATL     601.0
# 1                  1            2                9E    MSP  CVG    1359.0
# 2                  1            2                9E    DTW  CVG    1215.0
# 3                  1            2                9E    TLH  ATL    1521.0
# 4                  1            2                9E    ATL  FSM    1847.0
# ...              ...          ...               ...    ...  ...       ...
# 583980            31            4                UA    GUM  HNL     749.0
# 583981            31            4                UA    GUM  SPN     717.0
# 583982            31            4                UA    SPN  GUM     857.0
# 583983            31            4                UA    SPN  GUM    1820.0
# 583984            31            4                UA    GUM  SPN    1636.0
#
#        DEP_TIME_BLK  ARR_TIME  DISTANCE  DELAYED DIST_GROUP
# ...

# %%
df.drop(['DISTANCE'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  DEP_TIME  \
# 0             1            2                9E    GNV  ATL     601.0
# 1             1            2                9E    MSP  CVG    1359.0
# 2             1            2                9E    DTW  CVG    1215.0
# 3             1            2                9E    TLH  ATL    1521.0
# 4             1            2                9E    ATL  FSM    1847.0
#
#   DEP_TIME_BLK  ARR_TIME  DELAYED DIST_GROUP
# 0    0600-0659     722.0        0      SHORT
# 1    1400-1459    1633.0        0      SHORT
# 2    1200-1259    1329.0        0      SHORT
# 3    1500-1559    1625.0        0      SHORT
# 4    1900-1959    1940.0        0      SHORT

# %%
from sklearn.preprocessing import LabelEncoder
label= LabelEncoder()
df['OP_UNIQUE_CARRIER']=label.fit_transform(df['OP_UNIQUE_CARRIER'])
df['ORIGIN']=label.fit_transform(df['ORIGIN'])
df['DEST']=label.fit_transform(df['DEST'])
df['DEP_TIME_BLK']=label.fit_transform(df['DEP_TIME_BLK'])
df['DIST_GROUP']=label.fit_transform(df['DIST_GROUP'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 566924 entries, 0 to 583984
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DAY_OF_MONTH       566924 non-null  int64
#  1   DAY_OF_WEEK        566924 non-null  int64
#  2   OP_UNIQUE_CARRIER  566924 non-null  int64
#  3   ORIGIN             566924 non-null  int64
#  4   DEST               566924 non-null  int64
#  5   DEP_TIME           566924 non-null  int64
#  6   DEP_TIME_BLK       566924 non-null  int64
#  7   ARR_TIME           566924 non-null  int64
#  8   DELAYED            566924 non-null  int64
#  9   DIST_GROUP         566924 non-null  int64
# dtypes: int64(10)
# memory usage: 47.6 MB

# %%
df['DEP_TIME']=df['DEP_TIME'].astype(int)
df['ARR_TIME']=df['ARR_TIME'].astype(int)

# %%
df
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  ORIGIN  DEST  DEP_TIME  \
# 0                  1            2                  0     128    19       601
# 1                  1            2                  0     225    80      1359
# 2                  1            2                  0      95    80      1215
# 3                  1            2                  0     325    19      1521
# 4                  1            2                  0      19   120      1847
# ...              ...          ...                ...     ...   ...       ...
# 583980            31            4                 13     139   145       749
# 583981            31            4                 13     139   312       717
# 583982            31            4                 13     312   139       857
# 583983            31            4                 13     312   139      1820
# 583984            31            4                 13     139   312      1636
#
# ...

# %%
x=df.drop(['DELAYED'],axis=1)
y=df['DELAYED']

# %%
x
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  ORIGIN  DEST  DEP_TIME  \
# 0                  1            2                  0     128    19       601
# 1                  1            2                  0     225    80      1359
# 2                  1            2                  0      95    80      1215
# 3                  1            2                  0     325    19      1521
# 4                  1            2                  0      19   120      1847
# ...              ...          ...                ...     ...   ...       ...
# 583980            31            4                 13     139   145       749
# 583981            31            4                 13     139   312       717
# 583982            31            4                 13     312   139       857
# 583983            31            4                 13     312   139      1820
# 583984            31            4                 13     139   312      1636
#
#         DEP_TIME_BLK  ARR_TIME  DIST_GROUP
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 583980    0
# 583981    0
# 583982    0
# 583983    0
# 583984    0
# Name: DELAYED, Length: 566924, dtype: int64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
xtest.shape
# Out:
# (113385, 9)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
dt.score(xtest,ytest)
# Out:
# 0.8670723640693213

# %%
df[df['DELAYED']==1]
# Out:
#         DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  ORIGIN  DEST  DEP_TIME  \
# 12                 1            2                  0      95    85      1552
# 16                 1            2                  0      95   109      1353
# 22                 1            2                  0      19   229      2216
# 43                 1            2                  0     120    19      1550
# 48                 1            2                  0      95   176      2036
# ...              ...          ...                ...     ...   ...       ...
# 583951            31            4                 13     238   154      1957
# 583974            31            4                 13     238   202       826
# 583976            31            4                 13     238   180       813
# 583977            31            4                 13      39   156      1105
# 583978            31            4                 13     238   232      1027
#
# ...

# %%
dt.predict([[31,4,13,238,202,826,3,1200,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
